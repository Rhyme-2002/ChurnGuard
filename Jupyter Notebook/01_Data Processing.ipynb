# %% [markdown]
# # Data Processing

# %%
import os
os.chdir("E:\Data Science\ML\Project")

# %%
import pandas as pd

# %%
df = pd.read_csv("data\ChurnGuard_raw.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10234 entries, 0 to 10233
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        10234 non-null  object
#  1   age                10234 non-null  int64
#  2   gender             10234 non-null  object
#  3   tenure_months      10234 non-null  int64
#  4   contract_type      10234 non-null  object
#  5   monthly_charges    10030 non-null  float64
#  6   total_charges      10030 non-null  float64
#  7   internet_service   10234 non-null  object
#  8   payment_method     10030 non-null  object
#  9   support_calls      10234 non-null  int64
#  10  late_payments      10234 non-null  int64
#  11  online_security    10030 non-null  object
#  12  tech_support       10030 non-null  object
#  13  streaming_service  10234 non-null  object
#  14  senior_citizen     10234 non-null  int64
#  15  family_members     10234 non-null  int64
#  16  churn              10234 non-null  int64
# dtypes: float64(2), int64(7), object(8)
# memory usage: 1.3+ MB

# %%
pd.isna(df).sum()
# Out:
# customer_id            0
# age                    0
# gender                 0
# tenure_months          0
# contract_type          0
# monthly_charges      204
# total_charges        204
# internet_service       0
# payment_method       204
# support_calls          0
# late_payments          0
# online_security      204
# tech_support         204
# streaming_service      0
# senior_citizen         0
# family_members         0
# churn                  0
# dtype: int64

# %%
ChurnGuard = df.dropna()

# %%
pd.isna(ChurnGuard).sum()
# Out:
# customer_id          0
# age                  0
# gender               0
# tenure_months        0
# contract_type        0
# monthly_charges      0
# total_charges        0
# internet_service     0
# payment_method       0
# support_calls        0
# late_payments        0
# online_security      0
# tech_support         0
# streaming_service    0
# senior_citizen       0
# family_members       0
# churn                0
# dtype: int64

# %%
ChurnGuard.drop(columns="customer_id", inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_28840\2882367761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ChurnGuard.drop(columns="customer_id", inplace=True)

# %%
ChurnGuard.duplicated().sum()
# Out:
# np.int64(0)

# %%
ChurnGuard.to_csv("data\ChurnGuard_processed.csv", index=False)
