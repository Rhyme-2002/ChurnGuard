# %% [markdown]
# # Exploratory Data Analysis

# %%
import os
os.chdir("E:\Data Science\ML\Project")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv("data\ChurnGuard_processed.csv")

# %% [markdown]
# ## Basic inspection

# %%
df.head()
# Out:
#    age  gender  tenure_months   contract_type  monthly_charges  total_charges  \
# 0   56  Female              9  Month-to-month            95.66        5386.54
# 1   46  Female             42        One year            67.43        5150.17
# 2   32    Male             46        Two year           147.75        2835.85
# 3   25  Female             21        Two year           146.54        4846.23
# 4   38  Female             22  Month-to-month            23.52        5332.26
#
#   internet_service    payment_method  support_calls  late_payments  \
# 0               No       Credit card              2              0
# 1              DSL      Mailed check              2              1
# 2               No       Credit card              6              1
# 3      Fiber optic       Credit card              1              2
# 4              DSL  Electronic check              3              1
#
#   online_security tech_support streaming_service  senior_citizen  \
# 0              No          Yes                No               1
# 1             Yes           No               Yes               0
# 2              No          Yes               Yes               0
# 3              No           No                No               1
# 4              No          Yes                No               0
#
#    family_members  churn
# 0               5      0
# 1               5      0
# 2               2      1
# 3               2      0
# 4               3      1

# %%
df.tail()
# Out:
#       age  gender  tenure_months   contract_type  monthly_charges  \
# 9254   23    Male             69  Month-to-month            69.18
# 9255   75  Female             24  Month-to-month           137.30
# 9256   23  Female             24        One year            24.80
# 9257   70    Male             45  Month-to-month            34.66
# 9258   19    Male             37        One year            73.59
#
#       total_charges internet_service payment_method  support_calls  \
# 9254        5216.74      Fiber optic    Credit card              2
# 9255        6389.86               No    Credit card              1
# 9256        6320.89              DSL  Bank transfer              5
# 9257         876.03      Fiber optic  Bank transfer              2
# 9258        2641.15              DSL   Mailed check              4
#
#       late_payments online_security tech_support streaming_service  \
# 9254              1              No           No               Yes
# 9255              0              No           No                No
# 9256              1              No          Yes                No
# 9257              2              No           No               Yes
# 9258              2             Yes           No               Yes
#
#       senior_citizen  family_members  churn
# 9254               0               2      0
# 9255               0               4      0
# 9256               0               2      0
# 9257               0               4      0
# 9258               0               5      0

# %%
df.shape
# Out:
# (9259, 16)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'tenure_months', 'contract_type', 'monthly_charges',
#        'total_charges', 'internet_service', 'payment_method', 'support_calls',
#        'late_payments', 'online_security', 'tech_support', 'streaming_service',
#        'senior_citizen', 'family_members', 'churn'],
#       dtype='object')

# %% [markdown]
# ## Summary statistics

# %%
df.describe()
# Out:
#                age  tenure_months  monthly_charges  total_charges  \
# count  9259.000000    9259.000000      9259.000000    9259.000000
# mean     46.684199      36.294416        84.984851    4517.290908
# std      16.736217      20.837461        37.689289    2572.128963
# min      18.000000       1.000000        20.000000     100.150000
# 25%      32.000000      18.000000        52.010000    2267.270000
# 50%      46.000000      36.000000        85.380000    4496.190000
# 75%      61.000000      54.000000       117.360000    6770.365000
# max      75.000000      72.000000       149.970000    8999.750000
#
#        support_calls  late_payments  senior_citizen  family_members  \
# count    9259.000000    9259.000000     9259.000000     9259.000000
# mean        1.991900       0.999460        0.161249        3.010152
# std         1.413388       0.995399        0.367780        1.413413
# min         0.000000       0.000000        0.000000        1.000000
# 25%         1.000000       0.000000        0.000000        2.000000
# 50%         2.000000       1.000000        0.000000        3.000000
# 75%         3.000000       2.000000        0.000000        4.000000
# max        10.000000       7.000000        1.000000        5.000000
#
#              churn
# count  9259.000000
# mean      0.232207
# std       0.422263
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df.describe(include="object")
# Out:
#         gender   contract_type internet_service payment_method  \
# count     9259            9259             9259           9259
# unique       2               3                3              4
# top     Female  Month-to-month      Fiber optic    Credit card
# freq      4641            5070             4672           2344
#
#        online_security tech_support streaming_service
# count             9259         9259              9259
# unique               2            2                 2
# top                 No           No                No
# freq              4680         4675              4667

# %%
df.describe(include="all")
# Out:
#                 age  gender  tenure_months   contract_type  monthly_charges  \
# count   9259.000000    9259    9259.000000            9259      9259.000000
# unique          NaN       2            NaN               3              NaN
# top             NaN  Female            NaN  Month-to-month              NaN
# freq            NaN    4641            NaN            5070              NaN
# mean      46.684199     NaN      36.294416             NaN        84.984851
# std       16.736217     NaN      20.837461             NaN        37.689289
# min       18.000000     NaN       1.000000             NaN        20.000000
# 25%       32.000000     NaN      18.000000             NaN        52.010000
# 50%       46.000000     NaN      36.000000             NaN        85.380000
# 75%       61.000000     NaN      54.000000             NaN       117.360000
# max       75.000000     NaN      72.000000             NaN       149.970000
#
#         total_charges internet_service payment_method  support_calls  \
# count     9259.000000             9259           9259    9259.000000
# unique            NaN                3              4            NaN
# top               NaN      Fiber optic    Credit card            NaN
# freq              NaN             4672           2344            NaN
# mean      4517.290908              NaN            NaN       1.991900
# std       2572.128963              NaN            NaN       1.413388
# min        100.150000              NaN            NaN       0.000000
# 25%       2267.270000              NaN            NaN       1.000000
# 50%       4496.190000              NaN            NaN       2.000000
# 75%       6770.365000              NaN            NaN       3.000000
# max       8999.750000              NaN            NaN      10.000000
#
#         late_payments online_security tech_support streaming_service  \
# count     9259.000000            9259         9259              9259
# unique            NaN               2            2                 2
# top               NaN              No           No                No
# freq              NaN            4680         4675              4667
# mean         0.999460             NaN          NaN               NaN
# std          0.995399             NaN          NaN               NaN
# min          0.000000             NaN          NaN               NaN
# 25%          0.000000             NaN          NaN               NaN
# 50%          1.000000             NaN          NaN               NaN
# 75%          2.000000             NaN          NaN               NaN
# max          7.000000             NaN          NaN               NaN
#
#         senior_citizen  family_members        churn
# count      9259.000000     9259.000000  9259.000000
# unique             NaN             NaN          NaN
# top                NaN             NaN          NaN
# freq               NaN             NaN          NaN
# mean          0.161249        3.010152     0.232207
# std           0.367780        1.413413     0.422263
# min           0.000000        1.000000     0.000000
# 25%           0.000000        2.000000     0.000000
# 50%           0.000000        3.000000     0.000000
# 75%           0.000000        4.000000     0.000000
# max           1.000000        5.000000     1.000000

# %% [markdown]
# ## Check data types

# %%
df.dtypes
# Out:
# age                    int64
# gender                object
# tenure_months          int64
# contract_type         object
# monthly_charges      float64
# total_charges        float64
# internet_service      object
# payment_method        object
# support_calls          int64
# late_payments          int64
# online_security       object
# tech_support          object
# streaming_service     object
# senior_citizen         int64
# family_members         int64
# churn                  int64
# dtype: object

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['gender', 'contract_type', 'internet_service', 'payment_method',
#        'online_security', 'tech_support', 'streaming_service'],
#       dtype='object')

# %%
df.select_dtypes(include=np.number).columns
# Out:
# Index(['age', 'tenure_months', 'monthly_charges', 'total_charges',
#        'support_calls', 'late_payments', 'senior_citizen', 'family_members',
#        'churn'],
#       dtype='object')

# %% [markdown]
# ## Check unique values

# %%
for col in df.columns:
    print(f"\n{col}")
    print(df[col].nunique())
    print(df[col].unique()[:10])
# Out:
# age
# 58
# [56 46 32 25 38 75 36 40 28 41]
#
# gender
# 2
# ['Female' 'Male']
#
# tenure_months
# 72
# [ 9 42 46 21 22 29 63 61 64 69]
#
# contract_type
# 3
# ['Month-to-month' 'One year' 'Two year']
#
# monthly_charges
# 6610
# [ 95.66  67.43 147.75 146.54  23.52 114.64 126.16  26.91  95.27 124.25]
#
# total_charges
# 9207
# [5386.54 5150.17 2835.85 4846.23 5332.26 8516.03 6901.12 4000.63 4344.23
#  5866.52]
#
# internet_service
# 3
# ['No' 'DSL' 'Fiber optic']
#
# payment_method
# 4
# ['Credit card' 'Mailed check' 'Electronic check' 'Bank transfer']
#
# support_calls
# 11
# [2 6 1 3 0 4 5 7 8 9]
#
# late_payments
# 8
# [0 1 2 4 3 5 6 7]
#
# online_security
# 2
# ['No' 'Yes']
#
# tech_support
# 2
# ['Yes' 'No']
#
# streaming_service
# 2
# ['No' 'Yes']
#
# senior_citizen
# 2
# [1 0]
#
# family_members
# 5
# [5 2 3 1 4]
#
# churn
# 2
# [0 1]

# %% [markdown]
# ## Target variable analysis

# %%
df["churn"].value_counts()
# Out:
# churn
# 0    7109
# 1    2150
# Name: count, dtype: int64

# %%
df["churn"].value_counts(normalize=True) * 100
# Out:
# churn
# 0    76.77935
# 1    23.22065
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df, x="churn")
plt.title("Customer Churn Distribution")
plt.show()

# %% [markdown]
# ## Numerical variable distribution

# %%
df.hist(figsize=(15, 12), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation

# %%
corr = df.select_dtypes(include=np.number).corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, fmt=".2f")

plt.title("Correlation Matrix")
plt.show()
